# %% [markdown]
# <a href="https://colab.research.google.com/github/IdaSharonJ/Python-exercises/blob/main/12_SEP_Freq_Dist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("bank-direct-marketing-campaigns.csv")
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  campaign  pdays  previous     poutcome  emp.var.rate  \
# 0   may         mon         1    999         0  nonexistent           1.1
# 1   may         mon         1    999         0  nonexistent           1.1
# 2   may         mon         1    999         0  nonexistent           1.1
# 3   may         mon         1    999         0  nonexistent           1.1
# 4   may         mon         1    999         0  nonexistent           1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %%
df.shape
# Out:
# (41188, 20)

# %%
df.keys()
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'campaign', 'pdays', 'previous',
#        'poutcome', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx',
#        'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
jobs = pd.crosstab(index=df['job'],columns='Frequency')
jobs
# Out:
# col_0          Frequency
# job
# admin.             10422
# blue-collar         9254
# entrepreneur        1456
# housemaid           1060
# management          2924
# retired             1720
# self-employed       1421
# services            3969
# student              875
# technician          6743
# unemployed          1014
# unknown              330

# %%
months = pd.crosstab(index=df['month'],columns='Frequency')
months
# Out:
# col_0  Frequency
# month
# apr         2632
# aug         6178
# dec          182
# jul         7174
# jun         5318
# mar          546
# may        13769
# nov         4101
# oct          718
# sep          570

# %%
weekdays = pd.crosstab(index=df['day_of_week'],columns='Frequency')
weekdays
# Out:
# col_0        Frequency
# day_of_week
# fri               7827
# mon               8514
# thu               8623
# tue               8090
# wed               8134

# %%
contact = pd.crosstab(index=df['contact'],columns='Frequency')
contact
# Out:
# col_0      Frequency
# contact
# cellular       26144
# telephone      15044

# %%
sns.histplot(x='day_of_week',data=data, color = 'red')

# %%
sns.histplot(x='poutcome',data= df, color = 'green')

# %%
sns.histplot(x='education',data=data, color = 'blue')

# %%
sns.histplot(x='marital',data=data, color = 'pink')

# %%
sns.histplot(x='loan',data=df, color = 'yellow')

# %%
Price = pd.crosstab(index=df['cons.price.idx'],columns='Frequency')
Price
# Out:
# col_0           Frequency
# cons.price.idx
# 92.201                770
# 92.379                267
# 92.431                447
# 92.469                178
# 92.649                357
# 92.713                172
# 92.756                 10
# 92.843                282
# 92.893               5794
# 92.963                715
# 93.075               2458
# 93.200               3616
# 93.369                264
# 93.444               5175
# 93.749                174
# 93.798                 67
# 93.876                212
# 93.918               6685
# 93.994               7763
# 94.027                233
# 94.055                229
# 94.199                303
# 94.215                311
# 94.465               4374
# 94.601                204
# 94.767                128

# %%
Conf = pd.crosstab(index=df['cons.conf.idx'],columns='Frequency')
Conf
# Out:
# col_0          Frequency
# cons.conf.idx
# -50.8                128
# -50.0                282
# -49.5                204
# -47.1               2458
# -46.2               5794
# -45.9                 10
# -42.7               6685
# -42.0               3616
# -41.8               4374
# -40.8                715
# -40.4                 67
# -40.3                311
# -40.0                212
# -39.8                229
# -38.3                233
# -37.5                303
# -36.4               7763
# -36.1               5175
# -34.8                264
# -34.6                174
# -33.6                178
# -33.0                172
# -31.4                770
# -30.1                357
# -29.8                267
# -26.9                447

# %%
Euri = pd.crosstab(index=df['euribor3m'],columns='Frequency')
Euri
# Out:
# col_0      Frequency
# euribor3m
# 0.634              8
# 0.635             43
# 0.636             14
# 0.637              6
# 0.638              7
# ...              ...
# 4.967            643
# 4.968            992
# 4.970            172
# 5.000              7
# 5.045              9
#
# [316 rows x 1 columns]

# %%
days = pd.crosstab(index=df['pdays'],columns='Frequency')
days
# Out:
# col_0  Frequency
# pdays
# 0             15
# 1             26
# 2             61
# 3            439
# 4            118
# 5             46
# 6            412
# 7             60
# 8             18
# 9             64
# 10            52
# 11            28
# 12            58
# 13            36
# 14            20
# 15            24
# 16            11
# 17             8
# 18             7
# 19             3
# 20             1
# 21             2
# 22             3
# 25             1
# 26             1
# 27             1
# 999        39673

# %%
sns.histplot(x='education',data=df)

# %%
sns.histplot(x='campaign',data=df, color = 'red')
