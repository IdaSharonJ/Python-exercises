# %% [markdown]
# <a href="https://colab.research.google.com/github/IdaSharonJ/Python-exercises/blob/main/30AUG_EDA_US_CRIMES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data =pd.read_csv('uscrimes.csv') 
data.head(3)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (2,4,19) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    SNo  Incident ID Offence Code  CR Number Dispatch Date / Time NIBRS Code  \
# 0    0    201202980         3550  180042096      8/23/2018 21:52        35B
# 1    1    201181293         3522  180015424       3/30/2018 1:00        35A
# 2    2    201181293         3562  180015424       3/30/2018 1:00        35A
#
#    Victims            Crime Name1                Crime Name2  \
# 0        1  Crime Against Society  Drug Equipment Violations
# 1        1  Crime Against Society   Drug/Narcotic Violations
# 2        1  Crime Against Society   Drug/Narcotic Violations
#
#                              Crime Name3  ... End_Date_Time   Latitude  \
# 0       DRUGS - NARCOTIC EQUIP - POSSESS  ...           NaN  39.177744
# ...

# %%
data.describe()
# Out:
#                  SNo   Incident ID     CR Number        Victims  \
# count  306094.000000  3.060940e+05  3.060940e+05  306094.000000
# mean   153046.500000  2.012369e+08  1.692787e+08       1.022692
# std     88361.870986  8.626185e+04  6.210304e+07       0.192311
# min         0.000000  2.010871e+08  1.001107e+07       1.000000
# 25%     76523.250000  2.011625e+08  1.705431e+08       1.000000
# 50%    153046.500000  2.012361e+08  1.900183e+08       1.000000
# 75%    229569.750000  2.013109e+08  2.000466e+08       1.000000
# max    306093.000000  2.013872e+08  2.204211e+08      22.000000
#
#             Zip Code  Address Number       Latitude      Longitude  \
# count  302915.000000    2.799850e+05  306094.000000  306094.000000
# mean    20876.535939    8.393001e+03      38.146328     -75.269490
# std       170.157722    1.526296e+04       5.974082      11.786118
# min         6.000000    1.000000e+00       0.000000     -77.516753
# ...

# %%
data.columns
# Out:
# Index(['SNo', 'Incident ID', 'Offence Code', 'CR Number',
#        'Dispatch Date / Time', 'NIBRS Code', 'Victims', 'Crime Name1',
#        'Crime Name2', 'Crime Name3', 'Police District Name', 'Block Address',
#        'City', 'State', 'Zip Code', 'Agency', 'Place', 'Sector', 'Beat', 'PRA',
#        'Address Number', 'Street Prefix', 'Street Name', 'Street Suffix',
#        'Street Type', 'Start_Date_Time', 'End_Date_Time', 'Latitude',
#        'Longitude', 'Police District Number', 'Location', 'Year', 'Month',
#        'Year-Month', 'Day', 'Committed_At_Morning'],
#       dtype='object')

# %%
data.isna
# Out:
# <bound method DataFrame.isna of            SNo  Incident ID Offence Code  CR Number Dispatch Date / Time  \
# 0            0    201202980         3550  180042096      8/23/2018 21:52
# 1            1    201181293         3522  180015424       3/30/2018 1:00
# 2            2    201181293         3562  180015424       3/30/2018 1:00
# 3            3    201193163         3520  180029476      6/14/2018 22:26
# 4            4    201204355         2204  180043926       9/3/2018 12:06
# ...        ...          ...          ...        ...                  ...
# 306089  306089    201320571         1399  210006666       2/21/2021 7:25
# 306090  306090    201329875         2305  210017101       5/6/2021 22:54
# 306091  306091    201329751         5016  210016952       5/5/2021 22:38
# 306092  306092    201323117         9099  210009468      3/13/2021 12:07
# 306093  306093    201327806         2305  210014587      4/19/2021 14:17
#
#        NIBRS Code  Victims             Crime Name1  \
# ...

# %%
sns.distplot(data['Year'],kde=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.jointplot(x='Month',y='Crime Name1',data=data,color='red')

# %%
sns.rugplot(data['Month'],color='green')

# %%
sns.kdeplot(data['Year'])

# %%
sns.barplot(x='Crime Name1',y='Month',data=data,color='yellow')

# %%
sns.boxplot(y='Month',x='Victims',data=data,palette='jet_r')

# %%
sns.violinplot(x='Crime Name1',y='Year',data=data)

# %%
sns.stripplot(x='Month',y='Victims',data=data,palette='GnBu')

# %%
sns.displot(data=data, x="Month", hue="Police District Number", kind="kde", fill=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)

# %%
cordata=data.corr()
cordata
# Out:
#                            SNo  Incident ID  CR Number   Victims  Zip Code  \
# SNo                   1.000000    -0.082068   0.110573  0.009899  0.006189
# Incident ID          -0.082068     1.000000   0.760715  0.013088  0.001076
# CR Number             0.110573     0.760715   1.000000  0.007698  0.006721
# Victims               0.009899     0.013088   0.007698  1.000000  0.002335
# Zip Code              0.006189     0.001076   0.006721  0.002335  1.000000
# Address Number        0.006273    -0.000262   0.000188  0.003059  0.000025
# Latitude              0.169472    -0.200912  -0.104640  0.002284  0.004216
# Longitude            -0.169482     0.200862   0.104596 -0.002133 -0.003757
# Year                 -0.101082     0.982557   0.737079  0.013619  0.001141
# Month                -0.028184    -0.079034  -0.100946  0.001271  0.000121
# Day                   0.003778    -0.000770  -0.003182 -0.000896 -0.002566
# ...

# %%
sns.heatmap(cordata,annot=True,cmap='crest')
